# %% [markdown]
# # Setmana 2
# 27/2/2025

# %%
conjunt1={1,2,3, "hey"}
#conjunt2={5,6, conjunt1}
#dona error, per aixo hem de fer
conjunt2={5,6, frozenset(conjunt1)}
print(conjunt2)
# Out:
# {frozenset({1, 2, 3, 'hey'}), 5, 6}

# %% [markdown]
# Diccionaris

# %%
diccionari1 = {"clau1": 1, "clau2": 2, "clau3": 3}
print(diccionari1)
diccionari2 = {1:"hola", 2:"adeu", 3: "Python"}
print(diccionari2)
print(diccionari1["clau2"])
#Afegir una clau al diccionari
diccionari1["clau4"]=4
print(diccionari1)
#Eliminar una clau del diccionari
del diccionari1["clau1"]
print(diccionari1)
#Actualitzar un valor d'una clau
diccionari1["clau2"] = 100
print(diccionari1)
#Comprobar si una clau existeix
print("clau3" in diccionari1)
print("clau5" not in diccionari1)
# Obtenir totes les claus
print(diccionari1.keys())
# Obtenir tots els valors
print(diccionari1.values())
#Obtenir tots els elements del diccionari
print(diccionari1.items())
#Buidar el diccionari
diccionari1.clear()
print(diccionari1)
#Crear un diccionari buit
diccionari3 = {}
print(diccionari3)
#Copiar un diccionari
diccionari4 = diccionari2.copy()
print(diccionari4)
#Altres mètodes
diccionari4.get(2)
diccionari4.pop(2) #treu l'element amb la clau 2
print(diccionari4)
diccionari4.popitem() #treu l'ultim element del diccionari
print(diccionari4)
diccionari4.update({1:10, 2: 20})
print(diccionari4)
# Recorrer un diccionari
for key in diccionari2:
  print(key, diccionari2[key])
for key, value in diccionari2.items():
  print(key, value)
#Diccionaris dins de diccionaris
diccionari5 = {"a": 1, "b":{"x":100, "y":200}}
print(diccionari5)
print(diccionari5["b"]["y"])
#Afegir un diccionari a un diccionari existent
diccionari5["b"].update({"z":300})
print(diccionari5)
#Diccionaris dins de llistes
llista_diccionaris = [{"a":1},{"b":2}, {"c":3}]
print(llista_diccionaris[0])
print(llista_diccionaris[0]["a"])
#Llistes dins de diccionaris
diccionari_llistes = {"a":[1,2,3], "b":[4,5,6]}
print(diccionari_llistes["a"][0])
print(diccionari_llistes["b"][1])
# Out:
# {'clau1': 1, 'clau2': 2, 'clau3': 3}
# {1: 'hola', 2: 'adeu', 3: 'Python'}
# 2
# {'clau1': 1, 'clau2': 2, 'clau3': 3, 'clau4': 4}
# {'clau2': 2, 'clau3': 3, 'clau4': 4}
# {'clau2': 100, 'clau3': 3, 'clau4': 4}
# True
# True
# dict_keys(['clau2', 'clau3', 'clau4'])
# dict_values([100, 3, 4])
# dict_items([('clau2', 100), ('clau3', 3), ('clau4', 4)])
# {}
# {}
# {1: 'hola', 2: 'adeu', 3: 'Python'}
# {1: 'hola', 3: 'Python'}
# {1: 'hola'}
# {1: 10, 2: 20}
# 1 hola
# 2 adeu
# 3 Python
# 1 hola
# 2 adeu
# 3 Python
# {'a': 1, 'b': {'x': 100, 'y': 200}}
# 200
# {'a': 1, 'b': {'x': 100, 'y': 200, 'z': 300}}
# {'a': 1}
# 1
# 1
# 5

# %%
#veure quin es l'objecte
print(id(diccionari1))
d=diccionari1
print(id(d))
d=diccionari1.copy()
print(id(d))
# Out:
# 135093299302656
# 135093299302656
# 135093299284864

# %%
diccionari2.values() #per veure valors
diccionari2.items() #valors i id
# Out:
# dict_items([(1, 'hola'), (2, 'adeu'), (3, 'Python')])

# %%
llistabuida = []
print(llistabuida)
# Out:
# []

# %%
llista=[]
llista.append(2)
llista.append(28)
llista.append(798)
llista.append(318)
print(llista)
# Out:
# [2, 28, 798, 318]

# %%
tupla = tuple()
conjunt = {}
type(conjunt)

cadena0= "m'agraden simples"
cadenallarga= """Aquest es un text llarg
podem posar inglus espais i enters
molt de text hi cap"""
print(cadenallarga)
# Out:
# Aquest es un text llarg
# podem posar inglus espais i enters
# molt de text hi cap

# %%
#sequencies d'escapament
cadena = "per a que soni campana \b"
cadena = "per a que posi al principi de text \r que passa"
print(cadena)
print(cadenallarga[1])
print(cadenallarga[::])
print(cadenallarga[2:8])
print(cadenallarga[::2])
# Out:
#  que passa
# q
# Aquest es un text llarg
# podem posar inglus espais i enters
# molt de text hi cap
# uest e
# Aus su etlagpdmpsrigu sasietr
# otd eth a

# %%
str(cadena0)
cadenajunta = f"aixo es una llista amb coses dins com {4+2} sumes o una ajuntada amb una altra cadena {cadena0}"
print(cadenajunta)
# Out:
# aixo es una llista amb coses dins com 6 sumes o una ajuntada amb una altra cadena m'agraden simples
